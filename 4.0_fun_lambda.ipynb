# %% [markdown]
# # function
# A sub program of main program is called fun, fun  allowing you to reuse code rather than writing it
# multiple times for different inputs. fun has to types
# function definition and function call , every program must have fun definition else we get NameError.

# %%
def greet():
    print('hello')
    print('good evening')

# %%
def greet():
    print('hello')
    print('good evening')
greet()
# Out:
# hello
# good evening

# %%
def greet():
    print('hello')
    print('good evening')
greet()

def greet():
    print('hello')
    print('good evening')
greet()
# Out:
# hello
# good evening
# hello
# good evening

# %%
def greet():
    print('hello')
    print('good evening')
greet()

def greet():
    print('hello')
    print('good evening')
greet()
# Out:
# hello
# good evening
# hello
# good evening

# %%
def greet():
    print('hello')
    print('good noon')
greet()


def add(x,y):
    c=x+y
    print(c)
add(5,4)
# Out:
# hello
# good noon
# 9

# %%
def greet():
    print('hello')
    print('good noon')
    
def add(x,y,z):
    c=x+y
    print(c)

add(5,4)
greet()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 9
#       6     c=x+y
#       7     print(c)
# ----> 9 add(5,4)
#      10 greet()
#
# TypeError: add() missing 1 required positional argument: 'z'

# %%
def greet():
    print('hello')
    print('good noon')
greet()

def add(x,y):
    c=x+y
    return c

result = add(5,4)
print(result)
# Out:
# hello
# good noon
# 9

# %%
def add_sub(x,y): # what if i want to return 2 values add_sub & i want to return 2 values & function can accept multiple value 
    c= x+y
    d= x-y
    e= x*y
    return c, d, e 
    
add_sub(4,5)
# Out:
# (9, -1, 20)

# %%
def add_sub(x,y): # what if i want to return 2 values add_sub & i want to return 2 values & function can accept multiple value 
    c= x+y
    d= x-y
    e= x*y
    return c, d, e 
    
add_sub(4,5)
# Out:
# (9, -1, 20)

# %%
def person(name,age):
    print(name)
    print(age)
    
person('nit')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 5
#       2     print(name)
#       3     print(age)
# ----> 5 person('nit')
#
# TypeError: person() missing 1 required positional argument: 'age'

# %%
def person(name,age):
    print(name)
    print(age)
    
person(22, 'nit')
# Out:
# 22
# nit

# %%
def person(name,age):
    print(name)
    print(age-5)
    
person(22, 'nit')
# Out:
# 22
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 5
#       2     print(name)
#       3     print(age-5)
# ----> 5 person(22, 'nit')
#
# Cell In[31], line 3, in person(name, age)
#       1 def person(name,age):
#       2     print(name)
# ----> 3     print(age-5)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
def person(name,age):
    print(name)
    print(age-5)
    
person(age = 22, name='nit')
# Out:
# nit
# 17

# %%
def sum(a, b):
    c = a+b
    print(c)
    
sum(5,6)
# Out:
# 11

# %%
def sum(a, *b):
    c = a+b
    print(c)
    
sum(5,6,7, 8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 5
#       2     c = a+b
#       3     print(c)
# ----> 5 sum(5,6,7, 8)
#
# Cell In[34], line 2, in sum(a, *b)
#       1 def sum(a, *b):
# ----> 2     c = a+b
#       3     print(c)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
def sum(a, *b): # 1st argument is fixed & we fetch each value from the tuple & we can add them. 
    c = 7  
    for i in b:
        c = c + i 
    print(c)
        
sum(5,6,7,8,9,10)
# Out:
# 47

# %%
def add(num1, )

# %%
def add(num1,num2):
    return num1+num2
num1=10
num2=20
result(add(num1,num2))
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 5
#       3 num1=10
#       4 num2=20
# ----> 5 result(add(num1,num2))
#       6 print(result)
#
# TypeError: 'int' object is not callable

# %%
def add(k,h):
    return k+h
k=10
h=20
result=add(k,h)
print(result)
# Out:
# 30

# %%
def add(num1,num2):
    return num1+num2
num1=10
num2=20
result=add(num1,num2)
print(result)
# Out:
# 30

# %%
def factorial(n):# Function to calculate factorial of a number
    if n < 0:
        return "Factorial is not defined for negative numbers."
    elif n == 0 or n == 1:
        return 1
    else:
        result = 1
        for i in range(2, n + 1):
            result *= i
        return result

# Example usage
num = 10
print(f"The factorial of {num} is {factorial(num)}")
# Out:
# The factorial of 10 is 3628800

# %%
def factorial(n): # Recursive function to calculate factorial
    if n < 0:
        return "Factorial is not defined for negative numbers."
    elif n == 0 or n == 1:
        return 1
    else:
        return n * factorial(n - 1)

# Example usage
num = 10
print(f"The factorial of {num} is {factorial(num)}")
# Out:
# The factorial of 10 is 3628800

# %%
# program 1
# input: body
# process: body
# output: body

def sum():
    a=10
    b=20
    c=a+b
    print('sum of {} and {} ={}'.format(a,b,c))
#fun call
sum()
# Out:
# sum of 10 and 20 =30

# %%
# program 2
# input: call
# process: body
# output: call
def sum():
    c=a+b
# call
sum()
a=10
b=20
print(' sum of {} and {} ={}'.format(a,b,c))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 8
#       6     c=a+b
#       7 # call
# ----> 8 sum()
#       9 a=10
#      10 b=20
#
# Cell In[4], line 6, in sum()
#       5 def sum():
# ----> 6     c=a+b
#
# NameError: name 'a' is not defined

# %%
# program 2
# input: call
# process: body
# output: call
def sum(a,b):
    c=a+b
    return c
# call
sum(a,b)
a=10
b=20
print(' sum of {} and {} ={}'.format(a,b,c))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       7     return c
#       8 # call
# ----> 9 sum(a,b)
#      10 a=10
#      11 b=20
#
# NameError: name 'a' is not defined

# %%
# program 2
# input: call
# process: body
# output: call
def sum(a,b):
    c=a+b
    return c
# call

a=10
b=20
print(' sum of {} and {} ={}'.format(a,b,c))
sum(a,b)
# Out:
#  sum of 10 and 20 =30
# 30

# %%
# program 2
# input: call
# process: body
# output: call
def sum(a,b):
    c=a+b
    return c
# call
a=10
b=20
res=a+b
print(' sum of a and b ={}'.format(res))
sum(a,b)
# Out:
#  sum of a and b =30
# 30

# %%
# program 3
# input: body
# process: body
# output: call

def student():
    a=10
    b=20
    c=a+b
    return a,b,c

a,b,c=student()
print('sum of a and b ={}'.format(c))
# Out:
# sum of a and b =30

# %%
# program 4
# input: call
# process: body
# output: body
def student(a,b):
    c=a+b
    return c
    print(c)
a=10
b=20
student(a,b)
# Out:
# 30

# %% [markdown]
# # anomynous fun( lambda fun)
# anomynous fun also called as lambda fun because itzz used lambda kwd, contain single excutable statement .
#
# Used to write code for instant operations.

# %%
# code for adding two value using normal fun and lambda fun
def add(a,b):
    add= lambda a,b:a+b
    c=a+b
    
res=add(10,20)
res1=add(100,200)
print(res)
print(res1)
# Out:
# None
# None

# %%
# code for adding two value using normal fun and lambda fun
def add(a,b):
    add= lambda a,b:a+b
    c=a+b
    return c
res=add(10,20)
res1=add(100,200)
print(res)
print(res1)
# Out:
# 30
# 300
